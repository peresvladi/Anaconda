# %% [markdown]
# <a href="https://colab.research.google.com/github/peresvladi/Anaconda/blob/master/Train(2)_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data_frame = pd.read_csv('train (2).csv')

# %%
data_frame
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Общее колличество пассажиров: 891

# %%
data_frame.query('Survived == 1').agg({'Survived': 'sum'})
# Out:
# Survived    342
# dtype: int64

# %% [markdown]
# Количество спасшихся пасажиров: 342

# %%
data_frame.query('Survived == 0').describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   549.000000     549.0  549.000000  424.000000  549.000000  549.000000
# mean    447.016393       0.0    2.531876   30.626179    0.553734    0.329690
# std     260.640469       0.0    0.735805   14.172110    1.288399    0.823166
# min       1.000000       0.0    1.000000    1.000000    0.000000    0.000000
# 25%     211.000000       0.0    2.000000   21.000000    0.000000    0.000000
# 50%     455.000000       0.0    3.000000   28.000000    0.000000    0.000000
# 75%     675.000000       0.0    3.000000   39.000000    1.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    8.000000    6.000000
#
#              Fare
# count  549.000000
# mean    22.117887
# std     31.388207
# min      0.000000
# 25%      7.854200
# 50%     10.500000
# 75%     26.000000
# max    263.000000

# %% [markdown]
# Количество погибших пасажиров: 549

# %%
data_frame.query('Age > 18').describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   575.000000  575.000000  575.000000  575.000000  575.000000
# mean    449.328696    0.382609    2.158261   34.287826    0.332174
# std     254.405068    0.486447    0.851928   11.988352    0.574661
# min       1.000000    0.000000    1.000000   19.000000    0.000000
# 25%     232.500000    0.000000    1.000000   25.000000    0.000000
# 50%     448.000000    0.000000    2.000000   31.000000    0.000000
# 75%     665.500000    1.000000    3.000000   41.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    3.000000
#
#             Parch        Fare
# count  575.000000  575.000000
# mean     0.309565   35.224840
# std      0.816743   55.476982
# min      0.000000    0.000000
# 25%      0.000000    8.050000
# 50%      0.000000   14.400000
# 75%      0.000000   33.760400
# max      6.000000  512.329200

# %% [markdown]
# Количество мужчин и женщин на борту: 575

# %%
data_frame.query('Age > 18 and Survived == 1').describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   220.000000     220.0  220.000000  220.000000  220.000000  220.000000
# mean    457.409091       1.0    1.745455   34.438636    0.422727    0.372727
# std     244.466217       0.0    0.815785   11.243653    0.632767    0.756815
# min       2.000000       1.0    1.000000   19.000000    0.000000    0.000000
# 25%     271.500000       1.0    1.000000   26.000000    0.000000    0.000000
# 50%     455.000000       1.0    2.000000   32.000000    0.000000    0.000000
# 75%     646.500000       1.0    2.000000   40.250000    1.000000    0.000000
# max     890.000000       1.0    3.000000   80.000000    3.000000    5.000000
#
#              Fare
# count  220.000000
# mean    55.763391
# std     75.104437
# min      0.000000
# 25%     13.000000
# 50%     26.550000
# 75%     76.401075
# max    512.329200

# %% [markdown]
# Спаслось мужчин и женщин: 220

# %%
data_frame.query('Age > 18 and Survived == 0').describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   355.000000     355.0  355.000000  355.000000  355.000000  355.000000
# mean    444.321127       0.0    2.414085   34.194366    0.276056    0.270423
# std     260.588585       0.0    0.770446   12.442136    0.528687    0.850456
# min       1.000000       0.0    1.000000   19.000000    0.000000    0.000000
# 25%     212.000000       0.0    2.000000   24.000000    0.000000    0.000000
# 50%     440.000000       0.0    3.000000   31.000000    0.000000    0.000000
# 75%     672.500000       0.0    3.000000   41.500000    0.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    3.000000    6.000000
#
#              Fare
# count  355.000000
# mean    22.496723
# std     32.805463
# min      0.000000
# 25%      7.895800
# 50%     10.500000
# 75%     26.000000
# max    263.000000

# %% [markdown]
# Погибло мужчини и женщин: 355

# %%
data_frame.query('Age > 18 and Sex == "male" and Survived == 0').describe()
# Out:
#        PassengerId  Survived      Pclass         Age       SibSp       Parch  \
# count   313.000000     313.0  313.000000  313.000000  313.000000  313.000000
# mean    443.373802       0.0    2.367412   34.407348    0.246006    0.166134
# std     261.713383       0.0    0.785990   12.753056    0.519052    0.575574
# min       1.000000       0.0    1.000000   19.000000    0.000000    0.000000
# 25%     207.000000       0.0    2.000000   24.000000    0.000000    0.000000
# 50%     442.000000       0.0    3.000000   31.000000    0.000000    0.000000
# 75%     673.000000       0.0    3.000000   42.000000    0.000000    0.000000
# max     891.000000       0.0    3.000000   74.000000    3.000000    5.000000
#
#              Fare
# count  313.000000
# mean    22.799412
# std     33.914820
# min      0.000000
# 25%      7.895800
# 50%     10.500000
# 75%     26.000000
# max    263.000000

# %% [markdown]
# Погибло мужчин: 313

# %%
data_frame.query('Age > 18 and Sex == "female" and Survived == 0').describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    42.000000      42.0  42.000000  42.000000  42.000000  42.000000
# mean    451.380952       0.0   2.761905  32.607143   0.500000   1.047619
# std     255.017929       0.0   0.532345   9.800159   0.552158   1.738409
# min      19.000000       0.0   1.000000  20.000000   0.000000   0.000000
# 25%     252.750000       0.0   3.000000  25.000000   0.000000   0.000000
# 50%     430.500000       0.0   3.000000  30.000000   0.000000   0.000000
# 75%     653.250000       0.0   3.000000  40.750000   1.000000   1.000000
# max     886.000000       0.0   3.000000  57.000000   2.000000   6.000000
#
#              Fare
# count   42.000000
# mean    20.240974
# std     23.093011
# min      7.750000
# 25%      9.006250
# 50%     13.700000
# 75%     25.537500
# max    151.550000

# %% [markdown]
# Погибло женщин: 42

# %%
data_frame.query('Age < 18').describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   113.000000  113.000000  113.000000  113.000000  113.000000
# mean    429.212389    0.539823    2.584071    9.041327    1.460177
# std     281.743819    0.500632    0.677781    6.030408    1.625881
# min       8.000000    0.000000    1.000000    0.420000    0.000000
# 25%     172.000000    0.000000    2.000000    3.000000    0.000000
# 50%     420.000000    1.000000    3.000000    9.000000    1.000000
# 75%     721.000000    1.000000    3.000000   16.000000    3.000000
# max     876.000000    1.000000    3.000000   17.000000    5.000000
#
#             Parch        Fare
# count  113.000000  113.000000
# mean     1.053097   31.220798
# std      0.800008   32.538092
# min      0.000000    7.054200
# 25%      0.000000   12.287500
# 50%      1.000000   23.000000
# 75%      2.000000   34.375000
# max      3.000000  211.337500

# %% [markdown]
# Пассажиров на **борту** не достигших 18 лет: 113

# %%
data_frame.query('Age < 18').agg({'Survived': 'sum'})
# Out:
# Survived    61
# dtype: int64

# %% [markdown]
# Спаслось пассажиров из числа недостигших 18 лет: 61

# %%
data_frame.query('Survived == 0 and Age < 18').describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    52.000000      52.0  52.000000  52.000000  52.000000  52.000000
# mean    414.865385       0.0   2.923077  10.394231   2.269231   1.076923
# std     290.566791       0.0   0.334087   5.674450   1.858899   0.859689
# min       8.000000       0.0   1.000000   1.000000   0.000000   0.000000
# 25%     145.750000       0.0   3.000000   5.500000   0.000000   0.000000
# 50%     381.000000       0.0   3.000000  10.500000   3.000000   1.000000
# 75%     695.750000       0.0   3.000000  16.000000   4.000000   2.000000
# max     853.000000       0.0   3.000000  17.000000   5.000000   3.000000
#
#              Fare
# count   52.000000
# mean    26.954890
# std     21.759124
# min      7.054200
# 25%     10.490625
# 50%     27.900000
# 75%     32.134375
# max    151.550000

# %% [markdown]
# Погибло пассажиров из числа не достигших 18 летнего возраста: 52

# %%
data_frame.query('Pclass == 1').describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   216.000000  216.000000   216.0  186.000000  216.000000  216.000000
# mean    461.597222    0.629630     1.0   38.233441    0.416667    0.356481
# std     246.737616    0.484026     0.0   14.802856    0.611898    0.693997
# min       2.000000    0.000000     1.0    0.920000    0.000000    0.000000
# 25%     270.750000    0.000000     1.0   27.000000    0.000000    0.000000
# 50%     472.000000    1.000000     1.0   37.000000    0.000000    0.000000
# 75%     670.500000    1.000000     1.0   49.000000    1.000000    0.000000
# max     890.000000    1.000000     1.0   80.000000    3.000000    4.000000
#
#              Fare
# count  216.000000
# mean    84.154687
# std     78.380373
# min      0.000000
# 25%     30.923950
# 50%     60.287500
# 75%     93.500000
# max    512.329200

# %% [markdown]
# Пассажиров 1-го класса на борту: 216

# %%
data_frame.query('Pclass == 1').agg({'Survived': 'sum'})
# Out:
# Survived    136
# dtype: int64

# %% [markdown]
# Спаслось пассажиров 1-го класса: 136

# %%
data_frame.query('Pclass == 1 and Survived == 0').describe()
# Out:
#        PassengerId  Survived  Pclass        Age     SibSp      Parch  \
# count    80.000000      80.0    80.0  64.000000  80.00000  80.000000
# mean    410.300000       0.0     1.0  43.695312   0.28750   0.300000
# std     252.655587       0.0     0.0  15.284243   0.55561   0.700813
# min       7.000000       0.0     1.0   2.000000   0.00000   0.000000
# 25%     174.000000       0.0     1.0  31.000000   0.00000   0.000000
# 50%     437.000000       0.0     1.0  45.250000   0.00000   0.000000
# 75%     608.750000       0.0     1.0  55.250000   0.25000   0.000000
# max     873.000000       0.0     1.0  71.000000   3.00000   4.000000
#
#              Fare
# count   80.000000
# mean    64.684008
# std     60.662089
# min      0.000000
# 25%     27.742700
# 50%     44.750000
# 75%     78.937500
# max    263.000000

# %% [markdown]
# Погибло пассажиров 1-го класса: 80

# %%
data_frame.query('Pclass == 2').describe()
# Out:
#        PassengerId    Survived  Pclass         Age       SibSp       Parch  \
# count   184.000000  184.000000   184.0  173.000000  184.000000  184.000000
# mean    445.956522    0.472826     2.0   29.877630    0.402174    0.380435
# std     250.852161    0.500623     0.0   14.001077    0.601633    0.690963
# min      10.000000    0.000000     2.0    0.670000    0.000000    0.000000
# 25%     234.500000    0.000000     2.0   23.000000    0.000000    0.000000
# 50%     435.500000    0.000000     2.0   29.000000    0.000000    0.000000
# 75%     668.000000    1.000000     2.0   36.000000    1.000000    1.000000
# max     887.000000    1.000000     2.0   70.000000    3.000000    3.000000
#
#              Fare
# count  184.000000
# mean    20.662183
# std     13.417399
# min      0.000000
# 25%     13.000000
# 50%     14.250000
# 75%     26.000000
# max     73.500000

# %% [markdown]
# Пассажиров 2-го класса на борту: 184

# %%
data_frame.query('Pclass == 2').agg({'Survived': 'sum'})
# Out:
# Survived    87
# dtype: int64

# %% [markdown]
# Спаслось пассажиров 2-го класса: 87

# %%
data_frame.query('Pclass == 2 and Survived == 0').describe()
# Out:
#        PassengerId  Survived  Pclass        Age      SibSp      Parch  \
# count    97.000000      97.0    97.0  90.000000  97.000000  97.000000
# mean    452.123711       0.0     2.0  33.544444   0.319588   0.144330
# std     257.771065       0.0     0.0  12.151581   0.550500   0.432765
# min      21.000000       0.0     2.0  16.000000   0.000000   0.000000
# 25%     229.000000       0.0     2.0  25.000000   0.000000   0.000000
# 50%     414.000000       0.0     2.0  30.500000   0.000000   0.000000
# 75%     686.000000       0.0     2.0  39.000000   1.000000   0.000000
# max     887.000000       0.0     2.0  70.000000   2.000000   2.000000
#
#             Fare
# count  97.000000
# mean   19.412328
# std    15.307175
# min     0.000000
# 25%    11.500000
# 50%    13.000000
# 75%    26.000000
# max    73.500000

# %% [markdown]
# Погибло пассажиров 2-го класса: 97

# %%
data_frame.query('Pclass == 3').describe()

# %% [markdown]
# Пассажиров 3-го класса на борту: 491

# %%
data_frame.query('Pclass == 3').agg({'Survived': 'sum'})
# Out:
# Survived    119
# dtype: int64

# %% [markdown]
# Спаслось пассажиров 3-го класса: 119

# %%
data_frame.query('Pclass == 3 and Survived == 0').describe()
# Out:
#        PassengerId  Survived  Pclass         Age       SibSp       Parch  \
# count   372.000000     372.0   372.0  270.000000  372.000000  372.000000
# mean    453.580645       0.0     3.0   26.555556    0.672043    0.384409
# std     263.090509       0.0     0.0   12.334882    1.504700    0.914144
# min       1.000000       0.0     3.0    1.000000    0.000000    0.000000
# 25%     206.750000       0.0     3.0   19.000000    0.000000    0.000000
# 50%     470.000000       0.0     3.0   25.000000    0.000000    0.000000
# 75%     679.500000       0.0     3.0   33.000000    1.000000    0.000000
# max     891.000000       0.0     3.0   74.000000    8.000000    6.000000
#
#              Fare
# count  372.000000
# mean    13.669364
# std     12.118338
# min      0.000000
# 25%      7.750000
# 50%      8.050000
# 75%     15.136450
# max     69.550000

# %% [markdown]
# Погибло пассажиров 3-го класса: 372

# %%
df_new = data_frame
df_new
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def diff_of_male_sur():
  perc = there_were_of_male_sur()-percent_of_male_sur()
  return perc

def percent_of_male_sur():
  perc = int(df_new.query('Age > 18 and Sex == "male"').agg({'Survived': 'sum'}))
  return perc
  
def there_were_of_male_sur():
  perc = df_new.query('Age > 18 and Sex == "male"')
  return len(perc.axes[0])

def diff_of_female_sur():
  perc = there_were_of_female_sur() - percent_of_female_sur()
  return perc

def percent_of_female_sur():
  perc = int(df_new.query('Age > 18 and Sex == "female"').agg({'Survived': 'sum'}))
  return perc
    
def there_were_of_female_sur():
  perc = df_new.query('Age > 18 and Sex == "female"')
  return len(perc.axes[0])

def diff_passeng_are_children():
  perc = there_were_passeng_are_children()-surv_passeng_are_children()
  return perc
 
def surv_passeng_are_children():
  perc = int(df_new.query('Age < 18').agg({'Survived': 'sum'}))
  return perc
 
def there_were_passeng_are_children():
  perc = df_new.query('Age < 18')
  return len(perc.axes[0])

def diff_1cl_passeng():
  perc = there_were_1cl_passeng()-surv_1cl_passeng()
  return perc

def surv_1cl_passeng():
  perc = int(df_new.query('Pclass == 1').agg({'Survived': 'sum'}))
  return perc
  
def there_were_1cl_passeng():
  perc = df_new.query('Pclass == 1')
  return len(perc.axes[0])

def diff_2cl_passeng():
      perc = there_were_2cl_passeng()-surv_2cl_passeng()
      return perc

def surv_2cl_passeng():
      perc = int(df_new.query('Pclass == 2').agg({'Survived': 'sum'}))
      return perc
      
def there_were_2cl_passeng():
      perc = df_new.query('Pclass == 2')
      return len(perc.axes[0])

def diff_3cl_passeng():
  perc = there_were_3cl_passeng()-surv_3cl_passeng()
  return perc      

def surv_3cl_passeng():
  perc = int(df_new.query('Pclass == 3').agg({'Survived': 'sum'}))
  return perc

def there_were_3cl_passeng():
  perc = df_new.query('Pclass == 3')
  return len(perc.axes[0])

# %%
visuallist =[[there_were_of_male_sur(),there_were_of_female_sur(), there_were_passeng_are_children(), there_were_1cl_passeng(), there_were_2cl_passeng(), there_were_3cl_passeng()],
            [percent_of_male_sur(), percent_of_female_sur(), surv_passeng_are_children(), surv_1cl_passeng(), surv_2cl_passeng(), surv_3cl_passeng()],
            [diff_of_male_sur(), diff_of_female_sur(), diff_passeng_are_children(), diff_1cl_passeng(), diff_2cl_passeng(), diff_3cl_passeng()]]

# %%
df_m = pd.DataFrame(visuallist,
                  columns = ['male_sur', 'female_sur', 'passeng_are_children', '1cl_passeng', '2cl_passeng', '3cl_passeng'],
                  index=['there_were', 'were_saved', 'dead_passeng'])

# %%
df_m
# Out:
#               male_sur  female_sur  passeng_are_children  1cl_passeng  \
# there_were         382         193                   113          216
# were_saved          69         151                    61          136
# dead_passeng       313          42                    52           80
#
#               2cl_passeng  3cl_passeng
# there_were            184          491
# were_saved             87          119
# dead_passeng           97          372

# %%
df = df_m
df
# Out:
#               male_sur  female_sur  passeng_are_children  1cl_passeng  \
# there_were         382         193                   113          216
# were_saved          69         151                    61          136
# dead_passeng       313          42                    52           80
#
#               2cl_passeng  3cl_passeng
# there_were            184          491
# were_saved             87          119
# dead_passeng           97          372

# %%
x = ['male_sur', 'female_sur', 'passeng_are_children','1cl_passeng','2cl_passeng','3cl_passeng']
y = [313, 42, 52, 80,	97,	372]
sns.barplot(x=x, y=y);
